# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df_white = pd.read_excel("GP White .xlsx")

# %%
df_white.head()
# Out:
#    Race and Hispanic origin of householder  Number (thousands)  Total  \
# 0                                     2001               90680    100
# 1                                     2000               90030    100
# 2                                     1999               88890    100
# 3                                     1998               87210    100
# 4                                     1997               86110    100
#
#    Under $15,000 (%)  $15,000 to $24,999  (%)  $25,000 to $34,999 (%)  \
# 0                7.1                      8.8                     8.3
# 1                7.0                      8.5                     7.9
# 2                6.8                      8.5                     8.5
# 3                7.2                      8.6                     8.4
# 4                7.8                      8.9                     9.0
#
#    $35,000  to $49,999  (%)  $50,000 to $74,999  (%)  $75,000 to $99,999  (%)  \
# ...

# %%
df_white["Year"] = df_white["Race and Hispanic origin of householder"]

# %%
df_black = pd.read_excel("GP Black.xlsx")

# %%
df_black['Race and Hispanic origin of householder'].max()
# Out:
# 2001

# %%
df_white.keys()
# Out:
# Index(['Race and Hispanic origin of householder', 'Number (thousands)',
#        'Total', 'Under $15,000 (%)', '$15,000 to $24,999  (%)',
#        '$25,000 to $34,999 (%)', '$35,000  to $49,999  (%)',
#        '$50,000 to $74,999  (%)', '$75,000 to $99,999  (%)',
#        '$100,000 to $149,999  (%)', '$150,000 to $199,999  (%)',
#        '$200,000 and over  (%)', ' Median income Estimate  ($)',
#        'Median income Margin of error1 (±)  ($)', ' Mean income Estimate  ($)',
#        'Mean income Margin of error1 (±) ($)', 'Year'],
#       dtype='object')

# %%
df_black.head()
# Out:
#    Race and Hispanic origin of householder  Number (thousands)  Total  \
# 0                                     2001               13320    100
# 1                                     2000               13170    100
# 2                                     1999               12840    100
# 3                                     1998               12580    100
# 4                                     1997               12470    100
#
#    Under $15,000 (%)  $15,000 to $24,999  (%)  $25,000 to $34,999 (%)  \
# 0               16.9                     11.6                    10.9
# 1               16.1                     11.2                    10.9
# 2               16.9                     12.1                    10.5
# 3               19.0                     12.6                    11.1
# 4               18.5                     12.6                    11.4
#
#    $35,000  to $49,999  (%)  $50,000 to $74,999  (%)  $75,000 to $99,999  (%)  \
# ...

# %%
df_hispanic = pd.read_excel("GP Hispanic .xlsx")

# %%
df_hispanic.head()
# Out:
#    Race and Hispanic origin of householder  Number (thousands)  Total  \
# 0                                     2022               19320    100
# 1                                     2021               19230    100
# 2                                     2020               18340    100
# 3                                     2019               17670    100
# 4                                     2018               17760    100
#
#    Under $15,000 (%)  $15,000 to $24,999  (%)  $25,000 to $34,999 (%)  \
# 0                9.8                      8.1                     8.9
# 1               10.3                      7.6                     9.1
# 2                9.2                      8.7                     9.0
# 3                9.1                      7.7                     9.3
# 4                9.7                      9.5                    10.1
#
#    $35,000  to $49,999  (%)  $50,000 to $74,999  (%)  $75,000 to $99,999  (%)  \
# ...

# %%
df_asian = pd.read_excel("GP Asian.xlsx")

# %%
df_asian.head()
# Out:
#    Race and Hispanic origin of householder  Number (thousands)  Total  \
# 0                                     2022                7609    100
# 1                                     2021                7276    100
# 2                                     2020                7002    100
# 3                                     2019                6853    100
# 4                                     2018                6981    100
#
#    Under $15,000 (%)  $15,000 to $24,999  (%)  $25,000 to $34,999 (%)  \
# 0                7.5                      4.7                     4.5
# 1                7.3                      5.4                     5.6
# 2                6.3                      5.7                     4.6
# 3                5.7                      4.3                     4.9
# 4                7.5                      5.4                     5.6
#
#    $35,000  to $49,999  (%)  $50,000 to $74,999  (%)  $75,000 to $99,999  (%)  \
# ...

# %%
var1 = df_white[' Median income Estimate  ($)']
var2 = df_black[' Median income Estimate  ($)']

# %%
df_black[' Median income Estimate  ($)'].mean()
# Out:
# 37136.28571428572

# %%
plt.scatter(var1, df_white['Race and Hispanic origin of householder'], label = "White Median Income")
plt.scatter(var2, df_black['Race and Hispanic origin of householder'], label = "Black Median Income")
plt.xlabel("Median Income by Race")
plt.ylabel("Year")
plt.legend()
plt.savefig("Median income by race")
